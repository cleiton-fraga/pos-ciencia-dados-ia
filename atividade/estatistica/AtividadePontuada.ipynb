# %% [markdown]
# # **Universidade Tiradentes**
#
# Pós-Graduação em Ciência de Dados e Inteligência Artificial- Turma 2024/001
#
# Disciplina: Linguagens Python e R com Foco em Análise de Dados
#
# Aluno(s): Cleiton Alves Fraga, Rodolfo Brandão de Oliveira

# %% [markdown]
# **Instruções gerais**
# - Use este notebook como **template** para responder às questões.
# - Você poderá utilizar apenas **pandas**, **numpy** e **matplotlib**.
# - Comente seu código e **justifique** suas respostas numéricas com frases curtas.
# - O banco de dados é o **microdados ENEM (Nordeste)** previamente disponibilizado.
#
#  **Checklist mínimo por questão**
# - Código funcional, com comentários.
# - Tabelas/estatísticas corretas.
# - Gráficos legíveis (títulos, rótulos).
# - Resposta textual objetiva ao final de cada questão.
#
#   **Rubrica de Avaliação**
#
# - Correção técnica (40%) – código funcional e resultados corretos.
# - Clareza e organização (20%) – código comentado e estruturado.
# - Visualização (20%) – gráficos claros, bem rotulados e interpretados.
# - Análise crítica (20%) – justificativas e interpretações consistentes.

# %% [markdown]
# # **1. Crie uma função chamada `filtrar_colunas_enem(df)` que:**
#    - receba como entrada o DataFrame dos microdados do ENEM,
#    - retorne apenas as colunas **essenciais para análise de notas e informações básicas**,
#    - **exclua** as colunas referentes ao questionário socioeconômico (`Q001` a `Q025`).

# %%
import pandas as pd

path = '/Users/cleitonfraga/Documents/ciencia de dados/R/microdados_enem_nordeste.csv'
enem_df = pd.read_csv(path, sep=';', encoding='utf-8', encoding_errors='ignore')

def filtrar_colunas_enem(df):
    # Seleciona colunas essenciais, excluindo as do questionário socioeconômico
    colunas_essenciais = [col for col in df.columns if not col.startswith('Q') and col not in ['NU_INSCRICAO', 'TP_PRESENCA']]
    return df[colunas_essenciais]

enem_essencial = filtrar_colunas_enem(enem_df)
enem_essencial.head()
# Out:
#    NU_ANO TP_FAIXA_ETARIA   TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA  \
# 0    2023         17 anos  Feminino     Solteiro(a)       Parda
# 1    2023         18 anos  Feminino     Solteiro(a)       Parda
# 2    2023         23 anos  Maculino     Solteiro(a)       Parda
# 3    2023         22 anos  Feminino     Solteiro(a)       Parda
# 4    2023         19 anos  Feminino     Solteiro(a)      Branca
#
#   TP_NACIONALIDADE                                    TP_ST_CONCLUSAO  \
# 0    Brasileiro(a)  Estou cursando e concluirei o Ensino Médio em ...
# 1    Brasileiro(a)  Estou cursando e concluirei o Ensino Médio em ...
# 2    Brasileiro(a)                          Já concluí o Ensino Médio
# 3    Brasileiro(a)                          Já concluí o Ensino Médio
# 4    Brasileiro(a)  Estou cursando e concluirei o Ensino Médio em ...
#
#   TP_ANO_CONCLUIU      TP_ESCOLA       TP_ENSINO  ... NU_NOTA_LC  NU_NOTA_MT  \
# 0   Não informado        Pública  Ensino Regular  ...      507,2       466,7
# 1   Não informado        Pública  Ensino Regular  ...      446,9       338,3
# 2            2018  Não respondeu             NaN  ...      626,9       736,3
# 3            2019  Não respondeu             NaN  ...      388,5       415,6
# 4   Não informado        Pública  Ensino Regular  ...      544,4         437
#
#   TP_LINGUA  TP_STATUS_REDACAO NU_NOTA_COMP1 NU_NOTA_COMP2 NU_NOTA_COMP3  \
# 0    Ingles      Sem problemas         140.0         200.0         160.0
# 1    Ingles      Sem problemas         120.0         120.0         120.0
# 2    Ingles      Sem problemas         140.0         200.0         160.0
# 3  Espanhol      Sem problemas         120.0         120.0         100.0
# 4    Ingles      Sem problemas         160.0         180.0         160.0
#
#   NU_NOTA_COMP4  NU_NOTA_COMP5 NU_NOTA_REDACAO
# 0         180.0          200.0           880.0
# 1         120.0           80.0           560.0
# 2         160.0          200.0           860.0
# 3         120.0          100.0           560.0
# 4         180.0          200.0           880.0
#
# [5 rows x 42 columns]

# %% [markdown]
# #**Questão 2:**
#
# a) Crie uma tabela com as médias das notas (NU_NOTA_CN, NU_NOTA_CH, NU_NOTA_LC, NU_NOTA_MT) por estado (SG_UF_PROVA).
#
# b) Identifique quais estados tiveram menor e maior média em cada área.
#
# c) Selecione candidatos com média geral > 900 e mostre o grau de escolaridade do pai (Q001), da mãe (Q002) e renda familiar (Q006).
#
# d) Faça o mesmo para candidatos com média geral <

# %%
dados_filtrados_estado = enem_df[["SG_UF_PROVA", "NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]].copy()

# removendo linhas com valores nulos
dados_filtrados_estado.dropna(inplace=True)
dados_filtrados_estado.head()

# calculando a média das notas por estado
for col in ["NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]:
    dados_filtrados_estado[col] = dados_filtrados_estado[col].astype(str).str.replace(',', '.')
    dados_filtrados_estado[col] = pd.to_numeric(dados_filtrados_estado[col], errors='coerce')

media_por_estado = dados_filtrados_estado.groupby('SG_UF_PROVA')[["NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]].mean()

# estado com maior e menor média em cada área
maior_menor_media = {}
for col in ["NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]:
    maior_estado = media_por_estado[col].idxmax()
    menor_estado = media_por_estado[col].idxmin()
    maior_menor_media[col] = {'Maior': maior_estado, 'Menor': menor_estado}

display(maior_menor_media)


# candidatos com média geral > 900
enem_df["NU_NOTA_LC"] = pd.to_numeric(enem_df["NU_NOTA_LC"], errors='coerce')
enem_df["NU_NOTA_CN"] = pd.to_numeric(enem_df["NU_NOTA_CN"], errors='coerce')
enem_df["NU_NOTA_CH"] = pd.to_numeric(enem_df["NU_NOTA_CH"], errors='coerce')
enem_df["NU_NOTA_MT"] = pd.to_numeric(enem_df["NU_NOTA_MT"], errors='coerce')
enem_df["MEDIA_GERAL"] = enem_df[["NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]].mean(axis=1)
candidatos_maior_900 = enem_df[enem_df["MEDIA_GERAL"] > 900][["Q001", "Q002", "Q006"]]
candidatos_menor_900 = enem_df[enem_df["MEDIA_GERAL"] < 900][["Q001", "Q002", "Q006"]]

display(candidatos_maior_900)
display(candidatos_menor_900)
# Out:
# {'NU_NOTA_LC': {'Maior': 'RN', 'Menor': 'MA'},
#  'NU_NOTA_CN': {'Maior': 'RN', 'Menor': 'MA'},
#  'NU_NOTA_CH': {'Maior': 'RN', 'Menor': 'MA'},
#  'NU_NOTA_MT': {'Maior': 'RN', 'Menor': 'MA'}}
#                                                      Q001  \
# 6108    Nao completou a 4a serie/5o ano do ensino fund...
# 12387   Completou o Ensino Medio, mas nao completou a ...
# 13456                           Completou a Pos-graduacao
# 22611   Completou a Faculdade, mas nao completou a Pos...
# 68449                           Completou a Pos-graduacao
# ...                                                   ...
# 891588  Completou a Faculdade, mas nao completou a Pos...
# 903453  Completou a Faculdade, mas nao completou a Pos...
# 906026                          Completou a Pos-graduacao
# 933359  Completou o Ensino Medio, mas nao completou a ...
# 961719  Completou o Ensino Medio, mas nao completou a ...
#
#                                                      Q002  \
# 6108    Nao completou a 4a serie/5o ano do ensino fund...
# 12387   Completou o Ensino Medio, mas nao completou a ...
# 13456   Completou a Faculdade, mas nao completou a Pos...
# 22611   Completou a Faculdade, mas nao completou a Pos...
# 68449                           Completou a Pos-graduacao
# ...                                                   ...
# 891588  Completou a Faculdade, mas nao completou a Pos...
# 903453                          Completou a Pos-graduacao
# 906026                          Completou a Pos-graduacao
# 933359  Completou o Ensino Medio, mas nao completou a ...
# 961719                          Completou a Pos-graduacao
#
#                                      Q006
# 6108                      Ate R$ 1.320,00
# 12387                     Ate R$ 1.320,00
# 13456   De R$ 19.800,01 ate R$ 26.400,00.
# 22611              Acima de R$ 26.400,00.
# 68449    De R$ 15.840,01 ate R$19.800,00.
# ...                                   ...
# 891588   De R$ 15.840,01 ate R$19.800,00.
# 903453  De R$ 19.800,01 ate R$ 26.400,00.
# 906026   De R$ 15.840,01 ate R$19.800,00.
# 933359    De R$ 3.960,01 ate R$ 5.280,00.
# 961719  De R$ 13.200,01 ate R$ 15.840,00.
#
# [92 rows x 3 columns]
#                                                      Q001  \
# 0       Completou a 8a serie/9o ano do ensino fundamen...
# 4       Completou o Ensino Medio, mas nao completou a ...
# 5       Nao completou a 4a serie/5o ano do ensino fund...
# 7       Nao completou a 4a serie/5o ano do ensino fund...
# 8       Completou o Ensino Medio, mas nao completou a ...
# ...                                                   ...
# 994026  Nao completou a 4a serie/5o ano do ensino fund...
# 994027  Nao completou a 4a serie/5o ano do ensino fund...
# 994030                                            Nao sei
# 994031  Completou o Ensino Medio, mas nao completou a ...
# 994033  Completou a 8a serie/9o ano do ensino fundamen...
#
#                                                      Q002  \
# 0       Completou a 8a serie/9o ano do ensino fundamen...
# 4       Completou o Ensino Medio, mas nao completou a ...
# 5       Nao completou a 4a serie/5o ano do ensino fund...
# 7       Completou a 4a serie/5o ano, mas nao completou...
# 8       Completou o Ensino Medio, mas nao completou a ...
# ...                                                   ...
# 994026  Nao completou a 4a serie/5o ano do ensino fund...
# 994027  Nao completou a 4a serie/5o ano do ensino fund...
# 994030  Completou o Ensino Medio, mas nao completou a ...
# 994031  Completou o Ensino Medio, mas nao completou a ...
# 994033  Completou a 8a serie/9o ano do ensino fundamen...
#
#                                    Q006
# 0       De R$ 1.320,01 ate R$ 1.980,00.
# 4                       Ate R$ 1.320,00
# 5                       Ate R$ 1.320,00
# 7                       Ate R$ 1.320,00
# 8                       Ate R$ 1.320,00
# ...                                 ...
# 994026                  Ate R$ 1.320,00
# 994027  De R$ 1.320,01 ate R$ 1.980,00.
# 994030                    Nenhuma Renda
# 994031                  Ate R$ 1.320,00
# 994033  De R$ 1.320,01 ate R$ 1.980,00.
#
# [344717 rows x 3 columns]

# %% [markdown]
# #**Questão 3. Calcule o desvio padrão das notas em cada área por estado e identifique, para cada estado, qual área teve maior variação. Apresente uma tabela com `Estado` e `Área_com_maior_variação`.**

# %%
# Calculando o desvio padrão das notas por estado
desvio_padrao_por_estado = dados_filtrados_estado.groupby('SG_UF_PROVA')[["NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]].std()

# Identificando a área com maior variação para cada estado
area_maior_variacao = desvio_padrao_por_estado.idxmax(axis=1).reset_index()
area_maior_variacao.columns = ['Estado', 'Área_com_maior_variação']
display(area_maior_variacao)
# Out:
#   Estado Área_com_maior_variação
# 0     AL              NU_NOTA_MT
# 1     BA              NU_NOTA_MT
# 2     CE              NU_NOTA_MT
# 3     MA              NU_NOTA_MT
# 4     PA              NU_NOTA_MT
# 5     PB              NU_NOTA_MT
# 6     PI              NU_NOTA_MT
# 7     RN              NU_NOTA_MT
# 8     SE              NU_NOTA_MT

# %% [markdown]
# # **Questão 4 – Visualização de dados**
#
# a) Crie um boxplot das notas de `NU_NOTA_REDACAO` por estado (Nordeste).
#
# b) Crie um histograma das notas de `NU_NOTA_MT` para uma UF específica.
#
# Adicione título, rótulos e grade.
#
# Escreva 2–3 frases de interpretação dos gráficos.

# %% [markdown]
# a) Crie um boxplot das notas de `NU_NOTA_REDACAO` por estado (Nordeste).

# %%
import matplotlib.pyplot as plt


# Filtrar somente as colunas "SG_UF_PROVA", "NU_NOTA_REDACAO"
nota_redacao_por_estado_df = enem_df[["SG_UF_PROVA", "NU_NOTA_REDACAO"]]


# Criar boxplot utilizando o pacote "seaborn"
nota_redacao_por_estado_df.boxplot(column="NU_NOTA_REDACAO", by="SG_UF_PROVA", grid=False)


# Plotar o resultado
plt.title("Notas Prova Redação - Nordeste")
plt.suptitle("")
plt.xlabel("Estado")
plt.ylabel("Nota")
plt.show()

# %% [markdown]
# Interpretações:
# 1. A maioria das medianas está em torno de 600 pontos. Isso indica que, em geral, os alunos de todos os estados têm desempenhos centrais parecidos
# 2. Os estados CE, PI e PB parecem ter medianas ligeiramente mais altas (entre 600 e 650) em relação a MA e PA (entre 550 e 600)

# %% [markdown]
# b) Crie um histograma das notas de `NU_NOTA_MT` para uma UF específica.

# %%
import matplotlib.pyplot as plt


# Filtrar somente as colunas "SG_UF_PROVA", "NU_NOTA_MT"
nota_matematica_por_estado_df = enem_df[["SG_UF_PROVA", "NU_NOTA_MT"]]


# UF específica: SE
sigla_uf = 'SE'


# Selecionar as notas de matemática para a UF específica em um novo DataFrame
notas_mt = pd.DataFrame(
    nota_matematica_por_estado_df.loc[nota_matematica_por_estado_df["SG_UF_PROVA"] == sigla_uf, "NU_NOTA_MT"]
)


# Remover valores "NaN"
notas_mt = notas_mt.dropna()


# Criar histograma
nota_matematica_por_estado_df["NU_NOTA_MT"].hist(bins=20, figsize=(8,6))


# Plotar o resultado
plt.title(f"Notas de Matemática - UF: {sigla_uf}")
plt.xlabel("Nota")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# Interpretações:
# 1. É possível observar que a maior parte dos estudantes ficou com notas em torno de 400 pontos, com uma quantidade muito baixa de notas altas (de 800 pra cima)
# 2. Existe uma barra isolada na faixa da nota zero bastante alta (com cerca de 6 mil incritos). Isso pode indicar candidatos que não conseguiram responder a nenhuma questão, ou até mesmo ausência/desclassificação da prova
